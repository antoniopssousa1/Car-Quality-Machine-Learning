# %% [markdown]
# KNN ALGORITHM

# %% [markdown]
# We will be using this algorithm to classify cars in 4 categories based upon certain features.

# %%
from sklearn import preprocessing

# %%
import sklearn
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn import linear_model, preprocessing

# %%
data = pd.read_csv("car2.data")
print(data.head())  # To check if our data is loaded correctly
# Out:
#   buying  maint door persons lug_boot safety  class
# 0  vhigh  vhigh    2       2    small    low  unacc
# 1  vhigh  vhigh    2       2    small    med  unacc
# 2  vhigh  vhigh    2       2    small   high  unacc
# 3  vhigh  vhigh    2       2      med    low  unacc
# 4  vhigh  vhigh    2       2      med    med  unacc

# %% [markdown]
# As you may have noticed much of our data is not numeric. In order to train the K-Nearest Neighbor Classifier we must convert any string data into some kind of a number. Luckily for us sklearn has a method that can do this for us.
#
# We will start by creating a label encoder object and then use that to encode each column of our data into integers.

# %%
le = preprocessing.LabelEncoder()

# %% [markdown]
# The method fit_transform() takes a list (each of our columns) and will return to us an array containing our new values.

# %%
buying = le.fit_transform(list(data["buying"]))

# %%
maint = le.fit_transform(list(data["maint"]))
door = le.fit_transform(list(data["door"]))
persons = le.fit_transform(list(data["persons"]))
lug_boot = le.fit_transform(list(data["lug_boot"]))
safety = le.fit_transform(list(data["safety"]))
clss = le.fit_transform(list(data["class"]))

# %%
predict = "class"

# %%
#Combine our data into a feature list and a label list, we can use zip()
X = list(zip(buying, maint, door, persons, lug_boot, safety))  # features
y = list(clss) # labels

# %% [markdown]
# Finally we will split our data into training and testing data using the same process seen previously.

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.1) #Sample size aqui é 10% do Dataset

# %% [markdown]
# Training a KNN Classifier
# Creating a KNN Classifier is almost identical to how we created the linear regression model. The only difference is we can specify how many neighbors to look for as the argument n_neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=9)

# %% [markdown]
# To train our model we follow precisely the same steps as outlined earlier.

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %% [markdown]
# And once again to score our model we will do the following

# %%
acc = model.score(x_test, y_test)
print(acc)
# Out:
# 0.9421965317919075

# %% [markdown]
# Testing Our Model:
#
# If we'd like to see how our model is performing on the unique elements of our test data we can do the following.

# %%
predicted = model.predict(x_test)
names = ["unacc", "acc", "good", "vgood"]

for x in range(len(predicted)):
    print("Predicted: ", names[predicted[x]], "Data: ", x_test[x], "Actual: ", names[y_test[x]])
# Out:
# Predicted:  good Data:  (2, 1, 1, 1, 1, 2) Actual:  unacc
# Predicted:  unacc Data:  (1, 3, 2, 2, 0, 0) Actual:  unacc
# Predicted:  good Data:  (1, 3, 0, 1, 1, 2) Actual:  good
# Predicted:  unacc Data:  (3, 2, 1, 1, 1, 0) Actual:  unacc
# Predicted:  vgood Data:  (1, 1, 3, 1, 0, 0) Actual:  vgood
# Predicted:  unacc Data:  (1, 2, 0, 1, 0, 2) Actual:  acc
# Predicted:  good Data:  (0, 3, 0, 0, 0, 1) Actual:  good
# Predicted:  unacc Data:  (1, 2, 1, 1, 0, 2) Actual:  acc
# Predicted:  unacc Data:  (0, 1, 1, 2, 0, 0) Actual:  unacc
# Predicted:  unacc Data:  (1, 1, 0, 2, 1, 2) Actual:  unacc
# Predicted:  good Data:  (0, 0, 2, 0, 2, 2) Actual:  good
# Predicted:  good Data:  (3, 3, 0, 1, 1, 0) Actual:  good
# Predicted:  good Data:  (3, 0, 2, 2, 0, 2) Actual:  good
# Predicted:  good Data:  (2, 1, 2, 2, 0, 1) Actual:  good
# Predicted:  good Data:  (3, 3, 1, 2, 1, 1) Actual:  good
# Predicted:  good Data:  (0, 2, 3, 1, 1, 1) Actual:  good
# Predicted:  good Data:  (1, 2, 3, 2, 1, 1) Actual:  good
# Predicted:  good Data:  (3, 0, 0, 0, 1, 1) Actual:  good
# Predicted:  unacc Data:  (1, 0, 2, 1, 0, 2) Actual:  unacc
# Predicted:  good Data:  (1, 2, 2, 0, 2, 2) Actual:  good
# Predicted:  good Data:  (0, 0, 0, 0, 1, 0) Actual:  good
# Predicted:  unacc Data:  (1, 0, 1, 1, 1, 2) Actual:  unacc
# Predicted:  good Data:  (3, 3, 0, 2, 2, 0) Actual:  good
# Predicted:  acc Data:  (1, 2, 1, 1, 2, 0) Actual:  acc
# Predicted:  good Data:  (0, 0, 0, 1, 1, 1) Actual:  good
# Predicted:  good Data:  (2, 0, 3, 0, 2, 2) Actual:  good
# Predicted:  good Data:  (2, 3, 2, 1, 0, 1) Actual:  good
# Predicted:  good Data:  (2, 0, 0, 1, 2, 0) Actual:  unacc
# Predicted:  vgood Data:  (1, 0, 0, 2, 0, 0) Actual:  vgood
# Predicted:  good Data:  (0, 1, 0, 1, 1, 2) Actual:  good
# Predicted:  unacc Data:  (0, 1, 3, 2, 1, 0) Actual:  unacc
# Predicted:  good Data:  (1, 1, 1, 0, 1, 0) Actual:  good
# Predicted:  good Data:  (0, 0, 2, 0, 0, 2) Actual:  good
# Predicted:  good Data:  (0, 3, 1, 0, 1, 2) Actual:  good
# Predicted:  unacc Data:  (1, 0, 0, 2, 1, 0) Actual:  unacc
# Predicted:  good Data:  (3, 0, 1, 1, 2, 2) Actual:  good
# Predicted:  good Data:  (2, 0, 0, 2, 1, 1) Actual:  good
# Predicted:  good Data:  (0, 1, 3, 1, 1, 1) Actual:  good
# Predicted:  good Data:  (2, 3, 3, 0, 0, 0) Actual:  good
# Predicted:  vgood Data:  (2, 1, 1, 1, 1, 0) Actual:  acc
# Predicted:  good Data:  (3, 2, 1, 2, 1, 1) Actual:  good
# Predicted:  good Data:  (0, 1, 0, 0, 2, 1) Actual:  good
# Predicted:  good Data:  (2, 0, 2, 2, 2, 1) Actual:  good
# Predicted:  unacc Data:  (3, 2, 0, 1, 0, 0) Actual:  unacc
# Predicted:  unacc Data:  (1, 0, 2, 2, 0, 2) Actual:  unacc
# Predicted:  good Data:  (3, 1, 0, 0, 2, 0) Actual:  good
# Predicted:  good Data:  (0, 3, 2, 1, 2, 0) Actual:  good
# Predicted:  good Data:  (3, 0, 2, 0, 0, 0) Actual:  good
# Predicted:  good Data:  (0, 3, 1, 1, 2, 2) Actual:  good
# Predicted:  good Data:  (0, 2, 0, 1, 0, 1) Actual:  good
# Predicted:  good Data:  (0, 2, 1, 2, 0, 1) Actual:  good
# Predicted:  good Data:  (2, 1, 0, 1, 2, 1) Actual:  good
# Predicted:  good Data:  (1, 1, 3, 0, 2, 1) Actual:  good
# Predicted:  unacc Data:  (2, 0, 3, 2, 1, 0) Actual:  unacc
# Predicted:  good Data:  (2, 3, 0, 0, 1, 2) Actual:  good
# Predicted:  unacc Data:  (2, 2, 2, 2, 0, 2) Actual:  unacc
# Predicted:  good Data:  (3, 2, 3, 0, 0, 0) Actual:  good
# Predicted:  good Data:  (3, 0, 1, 2, 1, 0) Actual:  good
# Predicted:  good Data:  (3, 3, 2, 0, 1, 1) Actual:  good
# Predicted:  good Data:  (0, 3, 3, 2, 1, 0) Actual:  good
# Predicted:  good Data:  (3, 2, 1, 1, 1, 1) Actual:  good
# Predicted:  good Data:  (3, 0, 1, 1, 0, 0) Actual:  good
# Predicted:  good Data:  (0, 1, 3, 0, 2, 2) Actual:  good
# Predicted:  good Data:  (0, 2, 2, 1, 0, 1) Actual:  good
# Predicted:  good Data:  (2, 0, 2, 2, 1, 2) Actual:  unacc
# Predicted:  good Data:  (0, 3, 0, 0, 2, 1) Actual:  good
# Predicted:  unacc Data:  (2, 3, 2, 1, 1, 0) Actual:  unacc
# Predicted:  good Data:  (2, 2, 2, 2, 1, 1) Actual:  good
# Predicted:  good Data:  (2, 2, 2, 0, 2, 0) Actual:  good
# Predicted:  good Data:  (2, 0, 0, 0, 1, 2) Actual:  good
# Predicted:  good Data:  (2, 0, 2, 0, 0, 1) Actual:  good
# Predicted:  good Data:  (3, 1, 1, 1, 2, 1) Actual:  good
# Predicted:  good Data:  (1, 2, 3, 1, 0, 1) Actual:  good
# Predicted:  unacc Data:  (3, 2, 2, 1, 0, 0) Actual:  unacc
# Predicted:  good Data:  (1, 2, 1, 2, 2, 2) Actual:  unacc
# Predicted:  unacc Data:  (1, 0, 2, 2, 1, 2) Actual:  unacc
# Predicted:  good Data:  (0, 0, 1, 0, 2, 1) Actual:  good
# Predicted:  acc Data:  (1, 1, 2, 2, 0, 2) Actual:  acc
# Predicted:  good Data:  (0, 3, 1, 1, 0, 1) Actual:  good
# Predicted:  good Data:  (0, 3, 0, 2, 0, 2) Actual:  good
# Predicted:  acc Data:  (2, 1, 2, 2, 1, 2) Actual:  acc
# Predicted:  unacc Data:  (3, 1, 1, 1, 0, 2) Actual:  unacc
# Predicted:  good Data:  (0, 3, 3, 1, 1, 2) Actual:  good
# Predicted:  good Data:  (0, 1, 1, 2, 2, 1) Actual:  good
# Predicted:  good Data:  (0, 3, 0, 2, 2, 2) Actual:  good
# Predicted:  good Data:  (1, 1, 2, 2, 0, 1) Actual:  good
# Predicted:  acc Data:  (2, 1, 1, 1, 2, 0) Actual:  acc
# Predicted:  good Data:  (3, 0, 2, 1, 2, 0) Actual:  good
# Predicted:  good Data:  (0, 1, 0, 2, 2, 0) Actual:  good
# Predicted:  unacc Data:  (2, 1, 3, 2, 1, 2) Actual:  acc
# Predicted:  good Data:  (1, 3, 3, 2, 2, 1) Actual:  good
# Predicted:  good Data:  (3, 2, 3, 0, 1, 1) Actual:  good
# Predicted:  good Data:  (0, 3, 3, 1, 2, 0) Actual:  good
# Predicted:  good Data:  (0, 2, 3, 2, 1, 1) Actual:  good
# Predicted:  good Data:  (1, 2, 1, 2, 0, 1) Actual:  good
# Predicted:  good Data:  (0, 2, 3, 1, 2, 2) Actual:  good
# Predicted:  good Data:  (3, 2, 1, 0, 1, 0) Actual:  good
# Predicted:  unacc Data:  (0, 0, 2, 1, 2, 0) Actual:  unacc
# Predicted:  good Data:  (1, 3, 1, 0, 1, 0) Actual:  good
# Predicted:  unacc Data:  (2, 2, 1, 1, 1, 0) Actual:  unacc
# Predicted:  good Data:  (1, 1, 1, 1, 0, 1) Actual:  good
# Predicted:  acc Data:  (1, 1, 2, 2, 1, 2) Actual:  acc
# Predicted:  good Data:  (2, 3, 0, 1, 0, 1) Actual:  good
# Predicted:  good Data:  (3, 1, 3, 0, 2, 0) Actual:  good
# Predicted:  good Data:  (3, 0, 0, 2, 0, 0) Actual:  good
# Predicted:  good Data:  (1, 0, 3, 0, 1, 1) Actual:  good
# Predicted:  good Data:  (3, 1, 1, 0, 1, 0) Actual:  good
# Predicted:  good Data:  (3, 1, 3, 1, 2, 2) Actual:  good
# Predicted:  good Data:  (0, 1, 1, 0, 0, 1) Actual:  good
# Predicted:  good Data:  (0, 2, 1, 0, 1, 2) Actual:  good
# Predicted:  unacc Data:  (2, 3, 1, 2, 0, 0) Actual:  unacc
# Predicted:  unacc Data:  (3, 1, 3, 2, 0, 2) Actual:  unacc
# Predicted:  unacc Data:  (0, 2, 1, 1, 0, 0) Actual:  unacc
# Predicted:  unacc Data:  (2, 2, 1, 2, 2, 2) Actual:  unacc
# Predicted:  unacc Data:  (0, 1, 2, 1, 2, 0) Actual:  unacc
# Predicted:  good Data:  (1, 3, 2, 0, 2, 2) Actual:  good
# Predicted:  good Data:  (0, 2, 2, 0, 0, 1) Actual:  good
# Predicted:  good Data:  (2, 2, 1, 0, 2, 1) Actual:  good
# Predicted:  good Data:  (1, 0, 0, 1, 1, 1) Actual:  good
# Predicted:  unacc Data:  (2, 3, 0, 2, 0, 0) Actual:  unacc
# Predicted:  good Data:  (2, 0, 1, 0, 2, 0) Actual:  good
# Predicted:  good Data:  (0, 2, 3, 1, 2, 1) Actual:  good
# Predicted:  good Data:  (3, 2, 0, 2, 1, 1) Actual:  good
# Predicted:  good Data:  (1, 0, 2, 1, 1, 1) Actual:  good
# Predicted:  good Data:  (2, 0, 0, 0, 2, 2) Actual:  good
# Predicted:  good Data:  (1, 1, 0, 0, 1, 2) Actual:  good
# Predicted:  good Data:  (2, 0, 0, 0, 1, 1) Actual:  good
# Predicted:  good Data:  (0, 3, 3, 0, 2, 0) Actual:  good
# Predicted:  good Data:  (1, 2, 1, 2, 1, 1) Actual:  good
# Predicted:  good Data:  (1, 0, 3, 0, 0, 1) Actual:  good
# Predicted:  good Data:  (0, 3, 1, 2, 0, 1) Actual:  good
# Predicted:  good Data:  (2, 0, 0, 2, 2, 1) Actual:  good
# Predicted:  good Data:  (1, 1, 0, 2, 2, 1) Actual:  good
# Predicted:  good Data:  (2, 1, 0, 0, 2, 0) Actual:  good
# Predicted:  good Data:  (3, 2, 0, 1, 1, 2) Actual:  good
# Predicted:  good Data:  (1, 2, 0, 0, 2, 1) Actual:  good
# Predicted:  good Data:  (1, 0, 1, 2, 2, 1) Actual:  good
# Predicted:  good Data:  (0, 1, 0, 0, 2, 0) Actual:  good
# Predicted:  good Data:  (2, 0, 2, 0, 1, 2) Actual:  good
# Predicted:  good Data:  (1, 0, 1, 1, 2, 2) Actual:  unacc
# Predicted:  good Data:  (1, 0, 0, 2, 0, 1) Actual:  good
# Predicted:  unacc Data:  (1, 1, 0, 1, 1, 2) Actual:  unacc
# Predicted:  unacc Data:  (2, 1, 0, 1, 1, 2) Actual:  unacc
# Predicted:  unacc Data:  (0, 0, 1, 1, 1, 0) Actual:  unacc
# Predicted:  good Data:  (0, 1, 0, 1, 2, 2) Actual:  good
# Predicted:  unacc Data:  (0, 2, 3, 2, 0, 0) Actual:  unacc
# Predicted:  good Data:  (3, 0, 1, 0, 1, 1) Actual:  good
# Predicted:  unacc Data:  (1, 0, 0, 1, 0, 0) Actual:  vgood
# Predicted:  good Data:  (1, 2, 3, 0, 1, 2) Actual:  good
# Predicted:  unacc Data:  (0, 1, 1, 1, 2, 0) Actual:  unacc
# Predicted:  vgood Data:  (1, 0, 3, 1, 1, 0) Actual:  vgood
# Predicted:  good Data:  (3, 1, 1, 0, 1, 2) Actual:  good
# Predicted:  good Data:  (3, 0, 1, 0, 1, 2) Actual:  good
# Predicted:  good Data:  (0, 2, 3, 0, 1, 2) Actual:  good
# Predicted:  good Data:  (1, 1, 2, 0, 0, 1) Actual:  good
# Predicted:  good Data:  (1, 0, 0, 0, 2, 1) Actual:  good
# Predicted:  good Data:  (1, 1, 1, 0, 1, 1) Actual:  good
# Predicted:  good Data:  (3, 0, 3, 0, 1, 1) Actual:  good
# Predicted:  good Data:  (1, 2, 0, 0, 0, 1) Actual:  good
# Predicted:  good Data:  (1, 2, 1, 1, 2, 1) Actual:  good
# Predicted:  good Data:  (1, 1, 0, 0, 1, 1) Actual:  good
# Predicted:  good Data:  (2, 2, 3, 1, 1, 1) Actual:  good
# Predicted:  unacc Data:  (1, 0, 1, 2, 0, 2) Actual:  unacc
# Predicted:  good Data:  (3, 1, 3, 2, 1, 1) Actual:  good
# Predicted:  good Data:  (3, 3, 3, 1, 0, 2) Actual:  good
# Predicted:  good Data:  (2, 1, 0, 0, 1, 2) Actual:  good
# Predicted:  good Data:  (0, 3, 3, 0, 0, 0) Actual:  good
# Predicted:  good Data:  (0, 2, 3, 2, 2, 2) Actual:  good
# Predicted:  good Data:  (0, 1, 1, 2, 0, 1) Actual:  good
# Predicted:  good Data:  (0, 3, 3, 1, 2, 1) Actual:  good
# Predicted:  unacc Data:  (0, 0, 3, 2, 0, 0) Actual:  unacc
# Predicted:  acc Data:  (1, 1, 2, 2, 2, 0) Actual:  acc
# Predicted:  unacc Data:  (3, 2, 2, 2, 1, 0) Actual:  unacc

# %% [markdown]
# This will display the predicted class, our data and the actual class
# We create a names list so that we can convert our integer predictions into their string representation

# %% [markdown]
# ------------------------------------------------//---------------------------------------------------------

# %% [markdown]
# Looking at Neighbors
# The KNN model has a unique method that allows for us to see the neighbors of a given data point. We can use this information to plot our data and get a better idea of where our model may lack accuracy. We can use model.neighbors to do this.
#
# Note: the .neighbors method takes 2D as input, this means if we want to pass one data point we need surround it with [] so that it is in the right shape.
# Parameters: The parameters for .neighbors are as follows: data(2D array), # of neighbors(int), distance(True or False)
# Return: This will return to us an array with the index in our data of each neighbor. If distance=True then it will also return the distance to each neighbor from our data point.

# %%
predicted = model.predict(x_test)
names = ["unacc", "acc", "good", "vgood"]

for x in range(len(predicted)):
    print("Predicted: ", names[predicted[x]], "Data: ", x_test[x], "Actual: ", names[y_test[x]])
    # Now we will we see the neighbors of each point in our testing data
    n = model.kneighbors([x_test[x]], 9, True)
    print("N: ", n)
# Out:
# Predicted:  good Data:  (2, 1, 1, 1, 1, 2) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1537,  154, 1516,  304, 1098,  409,  663,  892,  295]],
#       dtype=int64))
# Predicted:  unacc Data:  (1, 3, 2, 2, 0, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1389,  597,  416,   78,  406, 1502, 1154,  101,  750]],
#       dtype=int64))
# Predicted:  good Data:  (1, 3, 0, 1, 1, 2) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 474, 1353, 1356,  229,  297,   92, 1457, 1469,  613]],
#       dtype=int64))
# Predicted:  unacc Data:  (3, 2, 1, 1, 1, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1430,  221, 1275,  551, 1529,  246,  489,    8,  476]],
#       dtype=int64))
# Predicted:  vgood Data:  (1, 1, 3, 1, 0, 0) Actual:  vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 827,  366,  876,  387, 1367, 1207, 1069, 1247,  960]],
#       dtype=int64))
# Predicted:  unacc Data:  (1, 2, 0, 1, 0, 2) Actual:  acc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 474, 1140,  883, 1094,  472,  529,  549, 1457,  639]],
#       dtype=int64))
# Predicted:  good Data:  (0, 3, 0, 0, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[200, 273, 213, 846, 611, 452, 931, 371, 248]], dtype=int64))
# Predicted:  unacc Data:  (1, 2, 1, 1, 0, 2) Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1130,  924, 1544, 1195,  206,  485,  518,  727, 1264]],
#       dtype=int64))
# Predicted:  unacc Data:  (0, 1, 1, 2, 0, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 403,   60,  748,  619, 1077,  963,  636,  564, 1085]],
#       dtype=int64))
# Predicted:  unacc Data:  (1, 1, 0, 2, 1, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1416,  623,  536,  741, 1454,  184,  639,  586,  196]],
#       dtype=int64))
# Predicted:  good Data:  (0, 0, 2, 0, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 414, 1022, 1504, 1045, 1317,  905,  852, 1223,  694]],
#       dtype=int64))
# Predicted:  good Data:  (3, 3, 0, 1, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[  23, 1377,  551, 1410, 1299,   47,  221,  867, 1284]],
#       dtype=int64))
# Predicted:  good Data:  (3, 0, 2, 2, 0, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 306,  379,  261, 1461, 1186,   54,  588,   77,  143]],
#       dtype=int64))
# Predicted:  good Data:  (2, 1, 2, 2, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 193,  587,   59,  522, 1157, 1141,  828,  198, 1303]],
#       dtype=int64))
# Predicted:  good Data:  (3, 3, 1, 2, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 192,  718, 1328,  985,  512,  938, 1396,  829,   31]],
#       dtype=int64))
# Predicted:  good Data:  (0, 2, 3, 1, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 818,  646, 1503,  131,  401, 1406, 1520,  280, 1468]],
#       dtype=int64))
# Predicted:  good Data:  (1, 2, 3, 2, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 470,  955, 1445,  401,  252,  836, 1147,  384,  577]],
#       dtype=int64))
# Predicted:  good Data:  (3, 0, 0, 0, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 543,  804,  601, 1449, 1117, 1086,  869,  202, 1038]],
#       dtype=int64))
# Predicted:  unacc Data:  (1, 0, 2, 1, 0, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 491, 1073, 1552,  921,  442, 1149,  314, 1181,  570]],
#       dtype=int64))
# Predicted:  good Data:  (1, 2, 2, 0, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 469,  870,  776, 1127,  434,   20,  844,  531,  744]],
#       dtype=int64))
# Predicted:  good Data:  (0, 0, 0, 0, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1515,  861,  988,  922, 1488,  791,  773,   71,  186]],
#       dtype=int64))
# Predicted:  unacc Data:  (1, 0, 1, 1, 1, 2) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1134,  892,  654, 1149,  314,  663,  733,  459, 1180]],
#       dtype=int64))
# Predicted:  good Data:  (3, 3, 0, 2, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 509,  715, 1410,   23,  282,  493,  829,  772,  468]],
#       dtype=int64))
# Predicted:  acc Data:  (1, 2, 1, 1, 2, 0) Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1282,  132,  484,  443,  242,  335,  266,  312, 1373]],
#       dtype=int64))
# Predicted:  good Data:  (0, 0, 0, 1, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 988,  791, 1208,  422,  971,  910,  451, 1319,  186]],
#       dtype=int64))
# Predicted:  good Data:  (2, 0, 3, 0, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 465, 1219,  841, 1000,  341, 1101, 1198,  873,  862]],
#       dtype=int64))
# Predicted:  good Data:  (2, 3, 2, 1, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1487,  617,  260,  328, 1012, 1173,  989,  929, 1411]],
#       dtype=int64))
# Predicted:  good Data:  (2, 0, 0, 1, 2, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1383,  937,  506,  326, 1378,   34, 1082, 1546,  324]],
#       dtype=int64))
# Predicted:  vgood Data:  (1, 0, 0, 2, 0, 0) Actual:  vgood
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[1217,  400, 1036, 1051,  655, 1351,   65,  819,  811]],
#       dtype=int64))
# Predicted:  good Data:  (0, 1, 0, 1, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 664,  422, 1080, 1208, 1139, 1416,  598, 1183,  462]],
#       dtype=int64))
# Predicted:  unacc Data:  (0, 1, 3, 2, 1, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 915,  600, 1311, 1539, 1412,  982,  325,  583, 1069]],
#       dtype=int64))
# Predicted:  good Data:  (1, 1, 1, 0, 1, 0) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1049,  864, 1142,  220,  135, 1159,  115,  573,  438]],
#       dtype=int64))
# Predicted:  good Data:  (0, 0, 2, 0, 0, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 244,   37, 1045,  175, 1073,  442,  455, 1500,  368]],
#       dtype=int64))
# Predicted:  good Data:  (0, 3, 1, 0, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1512, 1326, 1021,  388,  777, 1228,  835,   26,  842]],
#       dtype=int64))
# Predicted:  unacc Data:  (1, 0, 0, 2, 1, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 819,  372,  349, 1100,  107,  655,  811, 1160,  593]],
#       dtype=int64))
# Predicted:  good Data:  (3, 0, 1, 1, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 545,  923, 1397,  832, 1246, 1046,   33,  850, 1244]],
#       dtype=int64))
# Predicted:  good Data:  (2, 0, 0, 2, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 166,  516, 1393, 1106, 1061,  107,  655,  606, 1454]],
#       dtype=int64))
# Predicted:  good Data:  (0, 1, 3, 1, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 884, 1329,  915, 1423,  280, 1468,  554,  494, 1311]],
#       dtype=int64))
# Predicted:  good Data:  (2, 3, 3, 0, 0, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1428, 1184, 1135,  797,  152,   21, 1481,  260,  505]],
#       dtype=int64))
# Predicted:  vgood Data:  (2, 1, 1, 1, 1, 0) Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 500, 1231,  246,   90,  864,  409,  438, 1033,  249]],
#       dtype=int64))
# Predicted:  good Data:  (3, 2, 1, 2, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 946, 1430,   94,  157,  696,  300,  373,  294,    8]],
#       dtype=int64))
# Predicted:  good Data:  (0, 1, 0, 0, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 340,  858,  806,  968,  378,  274, 1347, 1515,  422]],
#       dtype=int64))
# Predicted:  good Data:  (2, 0, 2, 2, 2, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 291,  237,  687, 1323,  634,  243,  665,  197, 1321]],
#       dtype=int64))
# Predicted:  unacc Data:  (3, 2, 0, 1, 0, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 221, 1059,  380,  433,    2,  867,  369,  489,  695]],
#       dtype=int64))
# Predicted:  unacc Data:  (1, 0, 2, 2, 0, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 321,  571,  351, 1461, 1368,  458,  605,  314, 1134]],
#       dtype=int64))
# Predicted:  good Data:  (3, 1, 0, 0, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 437,  879,  759, 1241, 1401,  925, 1281, 1117,  506]],
#       dtype=int64))
# Predicted:  good Data:  (0, 3, 2, 1, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 356,  530,  547,  794,  457,  736,  331,  217, 1282]],
#       dtype=int64))
# Predicted:  good Data:  (3, 0, 2, 0, 0, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1442, 1221, 1023,  771,  649,  417,  391, 1016, 1286]],
#       dtype=int64))
# Predicted:  good Data:  (0, 3, 1, 1, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1021, 1326, 1400, 1366, 1138,  496, 1290,  973,  842]],
#       dtype=int64))
# Predicted:  good Data:  (0, 2, 0, 1, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[235, 883, 611, 661, 549,  40, 452, 537, 279]], dtype=int64))
# Predicted:  good Data:  (0, 2, 1, 2, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 279,  661, 1169,  833, 1077,  490,  809, 1039, 1130]],
#       dtype=int64))
# Predicted:  good Data:  (2, 1, 0, 1, 2, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 171,  784,  653, 1153,  937, 1218, 1144,  763,  326]],
#       dtype=int64))
# Predicted:  good Data:  (1, 1, 3, 0, 2, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 744,  293, 1070, 1499, 1003,  251, 1242,  308, 1124]],
#       dtype=int64))
# Predicted:  unacc Data:  (2, 0, 3, 2, 1, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 156, 1336,  557, 1002,   79,  510, 1265,   64, 1216]],
#       dtype=int64))
# Predicted:  good Data:  (2, 3, 0, 0, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 393,  877,  486, 1353,  211,  993,   38, 1469,   19]],
#       dtype=int64))
# Predicted:  unacc Data:  (2, 2, 2, 2, 0, 2) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 847,  660,   82,   41, 1234,  587,  584, 1303,   99]],
#       dtype=int64))
# Predicted:  good Data:  (3, 2, 3, 0, 0, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1481,  327,  616, 1428,   27,  524,  499,  649, 1459]],
#       dtype=int64))
# Predicted:  good Data:  (3, 0, 1, 2, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 362, 1090,   11, 1505, 1040, 1092,  301, 1020,  107]],
#       dtype=int64))
# Predicted:  good Data:  (3, 3, 2, 0, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[928, 721, 572, 926, 693, 218,  42,  84, 313]], dtype=int64))
# Predicted:  good Data:  (0, 3, 3, 2, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1539,  683,  534,  180, 1385, 1076,  109,  131,   72]],
#       dtype=int64))
# Predicted:  good Data:  (3, 2, 1, 1, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 701,  124,  629, 1404,  718, 1067,  778,  208,    8]],
#       dtype=int64))
# Predicted:  good Data:  (3, 0, 1, 1, 0, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 417, 1090,  630, 1023,  990,  362, 1467,  622, 1016]],
#       dtype=int64))
# Predicted:  good Data:  (0, 1, 3, 0, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 550, 1440, 1070,  308,  686, 1504,  852,  983,  450]],
#       dtype=int64))
# Predicted:  good Data:  (0, 2, 2, 1, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1201,  833,  227, 1503,   81,  646, 1288,  661, 1482]],
#       dtype=int64))
# Predicted:  good Data:  (2, 0, 2, 2, 1, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1323,  603,  868, 1461, 1324,  634,  379,  892,  605]],
#       dtype=int64))
# Predicted:  good Data:  (0, 3, 0, 0, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 931,  317,   76, 1088, 1232,  378,   35,  781, 1550]],
#       dtype=int64))
# Predicted:  unacc Data:  (2, 3, 2, 1, 1, 0) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 739,  855,  954, 1411, 1487,  743,  289,  706, 1521]],
#       dtype=int64))
# Predicted:  good Data:  (2, 2, 2, 2, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 828,   94,  587,  584,  479, 1360, 1340,  384,  410]],
#       dtype=int64))
# Predicted:  good Data:  (2, 2, 2, 0, 2, 0) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1114, 1341, 1335,  566, 1001,  430,  808, 1409,  825]],
#       dtype=int64))
# Predicted:  good Data:  (2, 0, 0, 0, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 446, 1365,  191,  601,  153,  787, 1180,  139, 1422]],
#       dtype=int64))
# Predicted:  good Data:  (2, 0, 2, 0, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 183,   62, 1221, 1510,  288, 1165, 1442, 1498,  483]],
#       dtype=int64))
# Predicted:  good Data:  (3, 1, 1, 1, 2, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1153, 1057,  476, 1019,  784,    8,  241, 1246, 1397]],
#       dtype=int64))
# Predicted:  good Data:  (1, 2, 3, 1, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 411, 1201,  387, 1445,  401, 1188,  960, 1503,  896]],
#       dtype=int64))
# Predicted:  unacc Data:  (3, 2, 2, 1, 0, 0) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1529,  489,  327,   27, 1210,  972,  224, 1553,  390]],
#       dtype=int64))
# Predicted:  good Data:  (1, 2, 1, 2, 2, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 574,    4, 1330,  223,    5, 1545, 1240,  752,  586]],
#       dtype=int64))
# Predicted:  unacc Data:  (1, 0, 2, 2, 1, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1149, 1134, 1056,  117, 1471,  605, 1305,  571, 1034]],
#       dtype=int64))
# Predicted:  good Data:  (0, 0, 1, 0, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1291,  340, 1317, 1022, 1078, 1257,  278,  274, 1488]],
#       dtype=int64))
# Predicted:  acc Data:  (1, 1, 2, 2, 0, 2) Actual:  acc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[  99, 1181,  458, 1303,  194,  857,  571, 1432,  623]],
#       dtype=int64))
# Predicted:  good Data:  (0, 3, 1, 1, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 882,  200,  712,  227, 1027,  842,  661,  452,  580]],
#       dtype=int64))
# Predicted:  good Data:  (0, 3, 0, 2, 0, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[  46,  374,  899,  596, 1371, 1010,  549,  279,  708]],
#       dtype=int64))
# Predicted:  acc Data:  (2, 1, 2, 2, 1, 2) Actual:  acc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[  17,  154,  828, 1303,  584, 1537,  159,  513, 1474]],
#       dtype=int64))
# Predicted:  unacc Data:  (3, 1, 1, 1, 0, 2) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 419, 1470,  355, 1369, 1098,  338, 1516,  165,  187]],
#       dtype=int64))
# Predicted:  good Data:  (0, 3, 3, 1, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 975,  100,  912,  233, 1361,  818,  519,  131,  777]],
#       dtype=int64))
# Predicted:  good Data:  (0, 1, 1, 2, 2, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 188,  965,  262,  473,  640, 1524,  395,  564,  635]],
#       dtype=int64))
# Predicted:  good Data:  (0, 3, 0, 2, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 973,  930,  496,  899, 1058,  992,   92, 1280,  742]],
#       dtype=int64))
# Predicted:  good Data:  (1, 1, 2, 2, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 782,  351,  815,  656, 1039,  432,  342,  644,  458]],
#       dtype=int64))
# Predicted:  acc Data:  (2, 1, 1, 1, 2, 0) Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 326,  132,  281, 1446,  784,  476, 1006, 1378,  266]],
#       dtype=int64))
# Predicted:  good Data:  (3, 0, 2, 1, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1084,  911,  673, 1517,  185,  239,  980,  207, 1246]],
#       dtype=int64))
# Predicted:  good Data:  (0, 1, 0, 2, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 188,  635,  319,  916, 1085, 1526,  172,  858, 1099]],
#       dtype=int64))
# Predicted:  unacc Data:  (2, 1, 3, 2, 1, 2) Actual:  acc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1172,  603,  108,  265,  871, 1236,  513, 1425,  470]],
#       dtype=int64))
# Predicted:  good Data:  (1, 3, 3, 2, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1147, 1391,  129,  671,  856,  836,  112,  785,  155]],
#       dtype=int64))
# Predicted:  good Data:  (3, 2, 3, 0, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 218,  528,  881,  616,  499, 1362,  926, 1164,  236]],
#       dtype=int64))
# Predicted:  good Data:  (0, 3, 3, 1, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 460,  534,  683, 1542,  356,   52,  766, 1520,  530]],
#       dtype=int64))
# Predicted:  good Data:  (0, 2, 3, 2, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1385, 1539,  814,  872,  961, 1311,  746,  577,  131]],
#       dtype=int64))
# Predicted:  good Data:  (1, 2, 1, 2, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 525,  782, 1226,  793,  656,  774,  485,  518,  403]],
#       dtype=int64))
# Predicted:  good Data:  (0, 2, 3, 1, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 818,  686, 1047,  912,  796,  550, 1408, 1554,  870]],
#       dtype=int64))
# Predicted:  good Data:  (3, 2, 1, 0, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 208, 1229,  765,  357, 1017, 1025,  111,  936, 1206]],
#       dtype=int64))
# Predicted:  unacc Data:  (0, 0, 2, 1, 2, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 477,  800, 1238, 1443, 1089,  838,  144, 1189,  278]],
#       dtype=int64))
# Predicted:  good Data:  (1, 3, 1, 0, 1, 0) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 413,  253,  812, 1230,  276,  454,  449,  220, 1465]],
#       dtype=int64))
# Predicted:  unacc Data:  (2, 2, 1, 1, 1, 0) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[111, 739, 627, 893, 976, 132, 918, 242, 124]], dtype=int64))
# Predicted:  good Data:  (1, 1, 1, 1, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[  24,  644,  782,  809,  722,  569, 1300, 1264, 1148]],
#       dtype=int64))
# Predicted:  acc Data:  (1, 1, 2, 2, 1, 2) Actual:  acc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1432, 1305, 1004,  513, 1474,  623,  342,  816, 1240]],
#       dtype=int64))
# Predicted:  good Data:  (2, 3, 0, 1, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 821, 1313,  684, 1543,  944, 1204,  332,  247, 1508]],
#       dtype=int64))
# Predicted:  good Data:  (3, 1, 3, 0, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1155,  130,  567,  440, 1050, 1451,  795,  207,  293]],
#       dtype=int64))
# Predicted:  good Data:  (3, 0, 0, 2, 0, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 362,  456,  301, 1483, 1467,  400, 1166,  120,  107]],
#       dtype=int64))
# Predicted:  good Data:  (1, 0, 3, 0, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 367, 1167, 1003,  350,   80,  873,  888,  251,  645]],
#       dtype=int64))
# Predicted:  good Data:  (3, 1, 1, 0, 1, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 246,  936,  666, 1206,  879, 1241,  864, 1016, 1281]],
#       dtype=int64))
# Predicted:  good Data:  (3, 1, 3, 1, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1331, 1477, 1161, 1547, 1278,  906,  947,  226,  190]],
#       dtype=int64))
# Predicted:  good Data:  (0, 1, 1, 0, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 809,  580, 1209,  831,  375, 1491,  722, 1132, 1185]],
#       dtype=int64))
# Predicted:  good Data:  (0, 2, 1, 0, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 381,  517,  148,    7, 1253,   26, 1199,   93, 1132]],
#       dtype=int64))
# Predicted:  unacc Data:  (2, 3, 1, 2, 0, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 878,  618, 1154,  179,   78,   25,  747,  996,  774]],
#       dtype=int64))
# Predicted:  unacc Data:  (3, 1, 3, 2, 0, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1425, 1186,   54,  318,  102, 1441, 1172,   49, 1331]],
#       dtype=int64))
# Predicted:  unacc Data:  (0, 2, 1, 1, 0, 0) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 661, 1482, 1077,  268, 1435,  963,  235, 1252,  712]],
#       dtype=int64))
# Predicted:  unacc Data:  (2, 2, 1, 2, 2, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1171, 1110,  780,  934,  423,  999, 1239,  141,  223]],
#       dtype=int64))
# Predicted:  unacc Data:  (0, 1, 2, 1, 2, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 951,  642, 1466,  711,  794, 1495,  123,   88,  734]],
#       dtype=int64))
# Predicted:  good Data:  (1, 3, 2, 0, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1071,  269, 1249,  467,  698,  495,  329,  798,  388]],
#       dtype=int64))
# Predicted:  good Data:  (0, 2, 2, 0, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1035,  602,  941, 1354,  831, 1507,  426,  580,  643]],
#       dtype=int64))
# Predicted:  good Data:  (2, 2, 1, 0, 2, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1293,  399,  702,  427, 1341, 1540, 1455,   85,  447]],
#       dtype=int64))
# Predicted:  good Data:  (1, 0, 0, 1, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 139,  166,  372,  651, 1180,  459,  504,  655,   65]],
#       dtype=int64))
# Predicted:  unacc Data:  (2, 3, 0, 2, 0, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1179,  996, 1543, 1105,  952,  684,    2, 1122, 1434]],
#       dtype=int64))
# Predicted:  good Data:  (2, 0, 1, 0, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 770,  790, 1128, 1415, 1006, 1378,  506,  970,  135]],
#       dtype=int64))
# Predicted:  good Data:  (0, 2, 3, 1, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1542, 1408,  113,  872,  648,  884, 1427, 1124,  642]],
#       dtype=int64))
# Predicted:  good Data:  (3, 2, 0, 2, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1492,  900,  891,  625,  283, 1067,  402,  829, 1192]],
#       dtype=int64))
# Predicted:  good Data:  (1, 0, 2, 1, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 459,  491, 1386,  367,  888,  749, 1149, 1009,  605]],
#       dtype=int64))
# Predicted:  good Data:  (2, 0, 0, 0, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 263, 1244,  787, 1387, 1394, 1422, 1200,  937, 1365]],
#       dtype=int64))
# Predicted:  good Data:  (1, 1, 0, 0, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1365,  638,  453,  664,  527, 1493,  968,  196, 1102]],
#       dtype=int64))
# Predicted:  good Data:  (2, 0, 0, 0, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 166,  139,  787, 1007, 1024,  869, 1038,  763,  922]],
#       dtype=int64))
# Predicted:  good Data:  (0, 3, 3, 0, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[1048,   52,  530,  766,  927,  515,  344,   14, 1408]],
#       dtype=int64))
# Predicted:  good Data:  (1, 2, 1, 2, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 168,  384, 1330, 1103, 1289,  816, 1511,  490,  752]],
#       dtype=int64))
# Predicted:  good Data:  (1, 0, 3, 0, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 183, 1031,  397,  953,   62,  645, 1310,  888, 1073]],
#       dtype=int64))
# Predicted:  good Data:  (0, 3, 1, 2, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1325, 1010,  592, 1226,  750, 1371, 1169, 1108,  661]],
#       dtype=int64))
# Predicted:  good Data:  (2, 0, 0, 2, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 176,  937,  653,   53,  197, 1370,   34, 1212,  504]],
#       dtype=int64))
# Predicted:  good Data:  (1, 1, 0, 2, 2, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 171,  653,  635,  609,  916, 1370, 1454,  262,  586]],
#       dtype=int64))
# Predicted:  good Data:  (2, 1, 0, 0, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 326, 1218,   69, 1006,  151,  506, 1281,  324,  135]],
#       dtype=int64))
# Predicted:  good Data:  (3, 2, 0, 1, 1, 2) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 761,  778, 1067,  283, 1109, 1243,  591, 1392,  398]],
#       dtype=int64))
# Predicted:  good Data:  (1, 2, 0, 0, 2, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[  29, 1540,  447, 1302, 1232,  203,  658,  968,  378]],
#       dtype=int64))
# Predicted:  good Data:  (1, 0, 1, 2, 2, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1160,  291,  197, 1524, 1398, 1370,  262,   66, 1034]],
#       dtype=int64))
# Predicted:  good Data:  (0, 1, 0, 0, 2, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 781,  734, 1515,  151, 1526, 1488, 1099,  274,  858]],
#       dtype=int64))
# Predicted:  good Data:  (2, 0, 2, 0, 1, 2) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 483, 1032, 1510,  868,  843, 1101,  967,  446,  465]],
#       dtype=int64))
# Predicted:  good Data:  (1, 0, 1, 1, 2, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1034, 1200,  740,  850,  984,   89,   66,  753, 1177]],
#       dtype=int64))
# Predicted:  good Data:  (1, 0, 0, 2, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1256,  377, 1393,   39,   65,  655, 1368, 1300, 1036]],
#       dtype=int64))
# Predicted:  unacc Data:  (1, 1, 0, 1, 1, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1180,  663,  196,  474,  651, 1140, 1493,  586, 1454]],
#       dtype=int64))
# Predicted:  unacc Data:  (2, 1, 0, 1, 1, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 741,  763, 1144,  591,  398,  191, 1382,  196,  516]],
#       dtype=int64))
# Predicted:  unacc Data:  (0, 0, 1, 1, 1, 0) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[988, 593,  88, 971, 477, 114, 789, 838, 773]], dtype=int64))
# Predicted:  good Data:  (0, 1, 0, 1, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1280,  806, 1444,  526, 1183,  858,  196, 1416,  422]],
#       dtype=int64))
# Predicted:  unacc Data:  (0, 2, 3, 2, 0, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 594,  600, 1076,  961, 1146,   18, 1539, 1295,  619]],
#       dtype=int64))
# Predicted:  good Data:  (3, 0, 1, 0, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1007, 1337, 1119,  936, 1016, 1286, 1342, 1246,  601]],
#       dtype=int64))
# Predicted:  unacc Data:  (1, 0, 0, 1, 0, 0) Actual:  vgood
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 372,  582,  913,   12,   65, 1351,  163,  593,  922]],
#       dtype=int64))
# Predicted:  good Data:  (1, 2, 3, 0, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1346, 1043,  776, 1345,  672,  502,  469, 1213, 1003]],
#       dtype=int64))
# Predicted:  unacc Data:  (0, 1, 1, 1, 2, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 734,  395,  477, 1373,  266,   88,  188, 1526,  858]],
#       dtype=int64))
# Predicted:  vgood Data:  (1, 0, 3, 1, 1, 0) Actual:  vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1207,   79, 1513,  436, 1367,  367, 1009,  156, 1167]],
#       dtype=int64))
# Predicted:  good Data:  (3, 1, 1, 0, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1516,   32, 1258, 1501,  272,  936,  419,  295,  435]],
#       dtype=int64))
# Predicted:  good Data:  (3, 0, 1, 0, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 601,  446, 1046,  545,  435,  843, 1286,  943,   32]],
#       dtype=int64))
# Predicted:  good Data:  (0, 2, 3, 0, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 100, 1440,  686,    9,  818,    7, 1406, 1346,  426]],
#       dtype=int64))
# Predicted:  good Data:  (1, 1, 2, 0, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 645, 1354,  762,  831,   95,  183,  644,  722, 1259]],
#       dtype=int64))
# Predicted:  good Data:  (1, 0, 0, 0, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1422,  139,  559,  787,  340,  504, 1078,  968,  922]],
#       dtype=int64))
# Predicted:  good Data:  (1, 1, 1, 0, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1137, 1476,  275,   86,  638,  722,   95,   24,  375]],
#       dtype=int64))
# Predicted:  good Data:  (3, 0, 3, 0, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1211,  350, 1152, 1164, 1119,  670,  612,   98,  843]],
#       dtype=int64))
# Predicted:  good Data:  (1, 2, 0, 0, 0, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[720, 448, 846, 883, 529,  97,  28, 611, 658]], dtype=int64))
# Predicted:  good Data:  (1, 2, 1, 1, 2, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1437, 1182, 1302, 1330,  447, 1103,  299,  199, 1545]],
#       dtype=int64))
# Predicted:  good Data:  (1, 1, 0, 0, 1, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 651,   28,  139, 1024,  658,  968,  573, 1347, 1493]],
#       dtype=int64))
# Predicted:  good Data:  (2, 2, 3, 1, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 479,  528, 1527,  950, 1362,   87, 1535, 1015,  401]],
#       dtype=int64))
# Predicted:  unacc Data:  (1, 0, 1, 2, 0, 2) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 458,  377, 1368,  745,   50, 1134,  314, 1160, 1300]],
#       dtype=int64))
# Predicted:  good Data:  (3, 1, 3, 2, 1, 1) Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 481,  604,   58, 1277,  133, 1441,  108, 1407, 1172]],
#       dtype=int64))
# Predicted:  good Data:  (3, 3, 3, 1, 0, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1104, 1399,  807,  316,  511,  210,  320,  420, 1012]],
#       dtype=int64))
# Predicted:  good Data:  (2, 1, 0, 0, 1, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 295, 1387, 1339, 1024,   32,  877,  153,  638, 1365]],
#       dtype=int64))
# Predicted:  good Data:  (0, 3, 3, 0, 0, 0) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1135,  758,  678,  643,  520,   52,  284,  941,  602]],
#       dtype=int64))
# Predicted:  good Data:  (0, 2, 3, 2, 2, 2) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 814,  872,   74,  685, 1266,  521, 1237, 1254,  912]],
#       dtype=int64))
# Predicted:  good Data:  (0, 1, 1, 2, 0, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 809,  564,  782,  964, 1039,  535,  121,  462, 1431]],
#       dtype=int64))
# Predicted:  good Data:  (0, 3, 3, 1, 2, 1) Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 131,  331,  856,  112,  912,  766,  648,  215, 1408]],
#       dtype=int64))
# Predicted:  unacc Data:  (0, 0, 3, 2, 0, 0) Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 600,  325,  817, 1433,  760, 1450,  475, 1081, 1551]],
#       dtype=int64))
# Predicted:  acc Data:  (1, 1, 2, 2, 2, 0) Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 385,  383,  123,  824,  707, 1466, 1320,  560,  542]],
#       dtype=int64))
# Predicted:  unacc Data:  (3, 2, 2, 2, 1, 0) Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 903, 1430,  719, 1074,  224, 1340,   94, 1529, 1248]],
#       dtype=int64))
